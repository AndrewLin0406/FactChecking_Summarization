# %%
import pandas as pd

df = pd.read_csv("/home/mila/l/lina/FactChecking/FactChecking_Summarization/RESULTS/METHOD1_Results_4_SUMMARY.csv")
res = df.to_dict(orient='records')
print(res)
# Out:
# [{'factcheck_analysis_link': 'https://www.politifact.com/factchecks/2022/feb/11/blog-posting/no-covid-19-vaccines-arent-responsible-increase-de/', 'factcheck_analysis_text': 'Research indicates that COVID-19 is likely responsible for the increase; there is no evidence to suggest the vaccines are to blame.\n\nSocial media users have suggested COVID-19 vaccines, rather than the illness itself, are responsible for the increase in deaths.\n\nOneAmerica CEO Scott Davison said life insurance industry data indicates death rates among working-age people were up 40% compared to pre-pandemic rates.\n\nAt the end of 2021, OneAmerica, an Indiana-based life insurance company, shared data about the ways the pandemic had impacted the life and disability insurance industry.\n\n"We are seeing right now the highest death rates we’ve ever seen in the history of this business — not just at OneAmerica, the data is consistent across every player in that business," said OneAmerica CEO Scott Davison in Dece
# ...

# %%
import json

with open('output.json', 'w', encoding='utf-8') as f:
    json.dump(res, f, indent=4)
